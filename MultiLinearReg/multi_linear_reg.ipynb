# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('50_Startups_EDA.csv')

# %%
dataset.isnull().sum()
# Out:
# R&D Spend          1
# Sales              1
# Administration     1
# Marketing Spend    2
# State              0
# Profit             0
# dtype: int64

# %%
df_1 = pd.get_dummies(dataset['State'])

# %%
df_1
# Out:
#     Chennai  Coimbatore  Trichy
# 0      True       False   False
# 1      True       False   False
# 2      True       False   False
# 3      True       False   False
# 4      True       False   False
# 5     False       False    True
# 6     False        True   False
# 7      True       False   False
# 8     False        True   False
# 9     False        True   False
# 10    False       False    True
# 11     True       False   False
# 12    False        True   False
# 13    False       False    True
# 14     True       False   False
# 15    False        True   False
# 16     True       False   False
# 17    False        True   False
# 18    False       False    True
# 19     True       False   False
# 20    False        True   False
# 21    False       False    True
# 22    False        True   False
# 23     True       False   False
# 24     True       False   False
# 25    False       False    True
# 26     True       False   False
# 27    False       False    True
# ...

# %%
df_1 = df_1.astype(int)

# %%
df_1
# Out:
#     Chennai  Coimbatore  Trichy
# 0         1           0       0
# 1         1           0       0
# 2         1           0       0
# 3         1           0       0
# 4         1           0       0
# 5         0           0       1
# 6         0           1       0
# 7         1           0       0
# 8         0           1       0
# 9         0           1       0
# 10        0           0       1
# 11        1           0       0
# 12        0           1       0
# 13        0           0       1
# 14        1           0       0
# 15        0           1       0
# 16        1           0       0
# 17        0           1       0
# 18        0           0       1
# 19        1           0       0
# 20        0           1       0
# 21        0           0       1
# 22        0           1       0
# 23        1           0       0
# 24        1           0       0
# 25        0           0       1
# 26        1           0       0
# 27        0           0       1
# ...

# %%
df_2 = pd.concat([dataset,df_1],axis=1)

# %%
df_2
# Out:
#     R&D Spend      Sales  Administration  Marketing Spend       State  \
# 0   210983.00  210983.00        20938.00           635.00     Chennai
# 1   327849.00  327849.00        28746.00           948.00     Chennai
# 2   210983.00  210983.00        20938.00              NaN     Chennai
# 3   327849.00  327849.00             NaN           948.00     Chennai
# 4   165349.20  165349.20       136897.80        471784.10     Chennai
# 5   162597.70  162597.70       151377.59        443898.53      Trichy
# 6   153441.51  153441.51       101145.55        407934.54  Coimbatore
# 7   144372.41  144372.41       118671.85        383199.62     Chennai
# 8   142107.34  142107.34        91391.77        366168.42  Coimbatore
# 9   142107.34  142107.34        91391.77        366168.42  Coimbatore
# 10  134615.46  134615.46       147198.87        127716.82      Trichy
# 11  131876.90  131876.90        99814.71        362861.36     Chennai
# ...

# %%
df_2.drop(columns=['State'],inplace=True)

# %%
df_2
# Out:
#     R&D Spend      Sales  Administration  Marketing Spend     Profit  Chennai  \
# 0   210983.00  210983.00        20938.00           635.00  210937.00        1
# 1   327849.00  327849.00        28746.00           948.00  384664.00        1
# 2   210983.00  210983.00        20938.00              NaN  210937.00        1
# 3   327849.00  327849.00             NaN           948.00  384664.00        1
# 4   165349.20  165349.20       136897.80        471784.10  192261.83        1
# 5   162597.70  162597.70       151377.59        443898.53  191792.06        0
# 6   153441.51  153441.51       101145.55        407934.54  191050.39        0
# 7   144372.41  144372.41       118671.85        383199.62  182901.99        1
# 8   142107.34  142107.34        91391.77        366168.42  166187.94        0
# 9   142107.34  142107.34        91391.77        366168.42  166187.94        0
# 10  134615.46  134615.46       147198.87        127716.82  156122.51        0
# ...

# %%
df_2.fillna(df_2.mean(numeric_only=True), inplace=True)

# %%
df_2
# Out:
#         R&D Spend          Sales  Administration  Marketing Spend     Profit  \
# 0   210983.000000  210983.000000    20938.000000       635.000000  210937.00
# 1   327849.000000  327849.000000    28746.000000       948.000000  384664.00
# 2   210983.000000  210983.000000    20938.000000    194802.922586  210937.00
# 3   327849.000000  327849.000000   116865.793051       948.000000  384664.00
# 4   165349.200000  165349.200000   136897.800000    471784.100000  192261.83
# 5   162597.700000  162597.700000   151377.590000    443898.530000  191792.06
# 6   153441.510000  153441.510000   101145.550000    407934.540000  191050.39
# 7   144372.410000  144372.410000   118671.850000    383199.620000  182901.99
# 8   142107.340000  142107.340000    91391.770000    366168.420000  166187.94
# 9   142107.340000  142107.340000    91391.770000    366168.420000  166187.94
# 10  134615.460000  134615.460000   147198.870000    127716.820000  156122.51
# ...

# %%
df_2.isnull().sum()
# Out:
# R&D Spend          0
# Sales              0
# Administration     0
# Marketing Spend    0
# Profit             0
# Chennai            0
# Coimbatore         0
# Trichy             0
# dtype: int64

# %%
df_2.duplicated().value_counts()
# Out:
# False    54
# True      6
# Name: count, dtype: int64

# %%
df_2.drop_duplicates(inplace=True)

# %%
df_2.shape
# Out:
# (54, 8)

# %%
df_2
# Out:
#         R&D Spend          Sales  Administration  Marketing Spend     Profit  \
# 0   210983.000000  210983.000000    20938.000000       635.000000  210937.00
# 1   327849.000000  327849.000000    28746.000000       948.000000  384664.00
# 2   210983.000000  210983.000000    20938.000000    194802.922586  210937.00
# 3   327849.000000  327849.000000   116865.793051       948.000000  384664.00
# 4   165349.200000  165349.200000   136897.800000    471784.100000  192261.83
# 5   162597.700000  162597.700000   151377.590000    443898.530000  191792.06
# 6   153441.510000  153441.510000   101145.550000    407934.540000  191050.39
# 7   144372.410000  144372.410000   118671.850000    383199.620000  182901.99
# 8   142107.340000  142107.340000    91391.770000    366168.420000  166187.94
# 10  134615.460000  134615.460000   147198.870000    127716.820000  156122.51
# 11  131876.900000  131876.900000    99814.710000    362861.360000  156991.12
# ...
